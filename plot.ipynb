# %%
import pandas as pd
import matplotlib.pyplot as plt
from JsonManager import *
from Plotter import *

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
alphaB = loadAlpha('alphaMultiCaminhos.json', "./betas_e_alphas")

# %%
alphaP = loadAlpha('alphaPolifasica.json', './betas_e_alphas')

# %%
betaB = loadBeta('betaMultiCaminhos.json','./betas_e_alphas')
betaP = loadBeta('betaPolifasica.json','./betas_e_alphas')

# %%
plotBeta(betaB,'Multi-caminhos',0,4)

# %%
plotBeta(betaP,'Polifásica', 0,4)

# %%
plotAlpha(alphaP, "Polifasica")

# %%
plotAlpha(alphaB, "pimba")

# %%
plotAlpha(alphaB, "pimba")

# %%
plotBeta(betaB, "multi")

# %%
def subplotAlphaBeta(alpha, beta, title):
    fig, axs = plt.subplots(1,2, figsize=(18,7))
    for c in alpha.columns:
        axs[0].plot(alpha[c], label=f"k = {c}")
    
    axs[0].legend()
    axs[0].set_title('Alpha(r) vs r')
    axs[0].set_xlabel("r")
    axs[0].grid()
    axs[0].set_ylabel("Alpha(r)")
    # axs[0].set_ylim(0, 900)

    axs[1].bar(beta.index, height=beta.values, color = 'tab:orange')
    axs[1].plot(beta.index, beta.values, label=f"m", marker='^', linestyle='--')
    axs[1].set_title('Beta(m, 0) vs m')
    axs[1].set_xlabel("m")
    axs[1].grid()
    # axs[1].set_ylim(0, 1)
    axs[1].set_ylabel("Beta(m,0)")

    plt.suptitle(title, fontsize=16)
    plt.show()

# %%
plotAlpha(alphaC, "Alpha(r) vs r na ordenação em Cascata")

# %%
plotAlpha(alphaP, "Alpha(r) vs r na ordenação Polifásica com m=3")

# %%
plotBeta(betaC, "Beta(m, 0) vs m na ordenação em Cascata com r=20")

# %%
plotBeta(betaP, "Beta(m, 0) vs m na ordenação Polifásica com r=20")

# %%
subplotAlphaBeta(alphaP, betaP, "Ordenação Polifásica")

# %%
subplotAlphaBeta(alphaC, betaC, "Ordenação em Cascata")

# %%
subplotAlphaBeta(alphaB, betaB, "Ordenação Multicaminhos")
