# %% [markdown]
# # Geração de Plots experimentais para os gráficos alpha(r) x r e beta(m, 0) x m

# %%
from helper.JsonManager import JsonManager
from helper.Plotter import Plotter

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Multi-Caminhos

# %% [markdown]
# Loading

# %%
alphaB = JsonManager.loadAlpha('alphaMultiCaminhos.json', './data/alpha')
betaB = JsonManager.loadBeta('betaMultiCaminhos.json', './data/beta')

# %%
Plotter.subplotAlphaBeta(alphaB, betaB, 'Ordenação Multi-Caminhos', 1, 14, 1.975, 2.025)

# %% [markdown]
# ## Polifásica

# %% [markdown]
# Loading

# %%
alphaP = JsonManager.loadAlpha('alphaPolifasica.json', './data/alpha')
betaP = JsonManager.loadBeta('betaPolifasica.json', './data/beta')

# %%
alphaP.min()
# Out:
# 4     2.9403
# 6     2.3894
# 8     1.6593
# 10    1.8797
# 12    1.0000
# dtype: float64

# %%
alphaP.max()
# Out:
# 4     837.1642
# 6     501.2327
# 8     358.6004
# 10    279.2919
# 12    228.8375
# dtype: float64

# %%
Plotter.subplotAlphaBeta(alphaP, betaP, 'Ordenação Polifásica', beta_ylim0=1.975, beta_ylim1=2.025)

# %% [markdown]
# ## Cascata

# %% [markdown]
# Loading

# %%
alphaC = JsonManager.loadAlpha('alphaCascata.json', './data/alpha')
betaC = JsonManager.loadBeta('betaCascata.json', './data/beta')

# %%
alphaC.min()
# Out:
# 4     3.2865
# 6     2.1930
# 8     2.0000
# 10    1.9789
# 12    1.0000
# dtype: float64

# %%
alphaC.max()
# Out:
# 4     834.5983
# 6     496.8612
# 8     357.0170
# 10    275.1182
# 12    223.2801
# dtype: float64

# %%
Plotter.subplotAlphaBeta(alphaC, betaC, 'Ordenação em Cascata', beta_ylim0=1.975, beta_ylim1=2.025)
